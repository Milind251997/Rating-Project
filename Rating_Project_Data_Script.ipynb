# %%
#Importing reqiured libraries
import selenium
import pandas as pd
from selenium import webdriver
import requests
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
import time
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, ElementClickInterceptedException

# %%
url = "https://www.amazon.in"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver =webdriver.Edge(executable_path = r"C:\Users\Admin\Desktop\FlipRobo Projects\documents\msedgedriver.exe")
driver.get(url)
driver.maximize_window()
# Out:
# Legality Response number from our URL is: <Response [200]>

# %% [markdown]
# # Laptop

# %%
# Let's enter the details in the search column
p_search=input("Enter product you want to search: ")
sear= driver.find_element_by_id("twotabsearchtextbox")
sear.send_keys(p_search)
sea_but=driver.find_element_by_id("nav-search-submit-button")
sea_but.click()
# Out:
# Enter product you want to search: Laptop

# %%
rating = []
review = []

# %%
#Searching for laptops
#Functions for getting products in all 2000 entries 
urls=[]
for k in range(17):
    for i in driver.find_elements_by_xpath("//div[@class='a-section a-spacing-medium']//h2"):
        urls.append(i.find_element_by_xpath(".//a").get_attribute('href'))
    try:
        next_page=driver.find_element_by_xpath("//div[@class='a-text-center']/ul/li[@class='a-last']/a").get_attribute('href')
        driver.get(next_page)
        driver.refresh()   
    except:
        break

#Taking every URL one after one
for i in urls:
    driver.get(i)
    urls.append(i)
    driver.implicitly_wait(5)
    
#Scraping the rating
    try:
        driver.find_element_by_xpath("//a[1][@id='acrCustomerReviewLink']").click()
    except NoSuchElementException:
        print("No rating")
        pass
    
#Scraping all the reviews
    try:
        driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
    except NoSuchElementException:
        pass

    
#Scrapping the details
    S_page=1
    E_page=60
    for page in range(S_page,E_page+1):
        try:
            reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
            for r in reviews:
                review.append(r.text.replace('\n',''))
        except NoSuchElementException:
            review.append("Not Available")
        try:
            Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
            for i in Rating:
                ratings=i.get_attribute('title')
                rating.append(ratings[:3])
        except NoSuchElementException:
            rating.append("Not available")      
            
        #Printing the page scrapped
        print("Product review and rating  of page {} scraped ".format(page+1))
        
        #Looping for going to next page automatically
        try:
            next_page=driver.find_element_by_xpath("//div[@id='cm_cr-pagination_bar']/ul/li[2]/a")
            if next_page.text=='Next Page':
                next_page.click()
                time.sleep(2)
        except NoSuchElementException:
            pass
# Out:
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# ...
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped

# %%
#Saving in a dataframe
lapdf=pd.DataFrame({'Reviews: ':review[:16000],'Ratings: ':rating[:16000]})

# %%
#Saving the data into a csv file
lapdf.to_csv('Laprev.csv')

# %%
Lapdf = pd.read_csv('Laprev.csv')
Lapdf.head()
# Out:
#    Unnamed: 0                                          Reviews:   Ratings:
# 0           0  Was excited for this laptop until it got deliv...        1.0
# 1           1  As with the looks its very sleek, lightweight ...        5.0
# 2           2                powerful machine but a bit heavy ..        5.0
# 3           3  its is a perfect banlance of hardware and pric...        5.0
# 4           4  Updated review after 6months of usage:All the ...        5.0

# %%
Lapdf.shape
# Out:
# (16800, 3)

# %% [markdown]
# # Mobile

# %%
# Let's enter the details in the search column
p_search=input("Enter product you want to search: ")
sear= driver.find_element_by_id("twotabsearchtextbox")
sear.send_keys(p_search)
sea_but=driver.find_element_by_id("nav-search-submit-button")
sea_but.click()
# Out:
# Enter product you want to search: Mobile

# %%
#Searching for laptops
#Functions for getting products in all 2000 entries 
urls=[]
for k in range(17):
    for i in driver.find_elements_by_xpath("//div[@class='a-section a-spacing-medium']//h2"):
        urls.append(i.find_element_by_xpath(".//a").get_attribute('href'))
    try:
        next_page=driver.find_element_by_xpath("//div[@class='a-text-center']/ul/li[@class='a-last']/a").get_attribute('href')
        driver.get(next_page)
        driver.refresh()   
    except:
        break

#Taking every URL one after one
for i in urls:
    driver.get(i)
    urls.append(i)
    driver.implicitly_wait(5)
    
#Scraping the rating
    try:
        driver.find_element_by_xpath("//a[1][@id='acrCustomerReviewLink']").click()
    except NoSuchElementException:
        print("No rating")
        pass
    
#Scraping all the reviews
    try:
        driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
    except NoSuchElementException:
        pass

    
#Scrapping the details
    S_page=1
    E_page=60
    for page in range(S_page,E_page+1):
        try:
            reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
            for r in reviews:
                review.append(r.text.replace('\n',''))
        except NoSuchElementException:
            review.append("Not Available")
        try:
            Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
            for i in Rating:
                ratings=i.get_attribute('title')
                rating.append(ratings[:3])
        except NoSuchElementException:
            rating.append("Not available")      
            
        #Printing the page scrapped
        print("Product review and rating  of page {} scraped ".format(page+1))
        
        #Looping for going to next page automatically
        try:
            next_page=driver.find_element_by_xpath("//div[@id='cm_cr-pagination_bar']/ul/li[2]/a")
            if next_page.text=='Next Page':
                next_page.click()
                time.sleep(2)
        except NoSuchElementException:
            pass
# Out:
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# No rating
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-9581fad79524> in <module>
#      37     for page in range(S_page,E_page+1):
#      38         try:
# ---> 39             reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
#      40             for r in reviews:
#      41                 review.append(r.text.replace('\n',''))
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     541             stacklevel=2,
#     542         )
# --> 543         return self.find_elements(by=By.XPATH, value=xpath)
#     544
#     545     def find_element_by_link_text(self, link_text) -> WebElement:
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
#    1277         # Return empty list if driver returns null
#    1278         # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1279         return self.execute(Command.FIND_ELEMENTS, {
#    1280             'using': by,
#    1281             'value': value})['value'] or []
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     420
#     421         params = self._wrap_value(params)
# --> 422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
#     424             self.error_handler.check_response(response)
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     419         data = utils.dump_json(params)
#     420         url = f"{self._url}{path}"
# --> 421         return self._request(command_info[0], url, body=data)
#     422
#     423     def _request(self, method, url, body=None):
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     441
#     442         if self.keep_alive:
# --> 443             resp = self._conn.request(method, url, body=body, headers=headers)
#     444             statuscode = resp.status
#     445         else:
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# F:\Users\Admin\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# F:\Users\Admin\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# F:\Users\Admin\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# F:\Users\Admin\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Smart watch

# %%
# Let's enter the details in the search column
p_search=input("Enter product you want to search: ")
sear= driver.find_element_by_id("twotabsearchtextbox")
sear.send_keys(p_search)
sea_but=driver.find_element_by_id("nav-search-submit-button")
sea_but.click()
# Out:
# Enter product you want to search: Smart Watch

# %%
rating = []
review = []

# %%
#Searching for laptops
#Functions for getting products in all 2000 entries 
urls=[]
for k in range(17):
    for i in driver.find_elements_by_xpath("//div[@class='a-section a-spacing-medium']//h2"):
        urls.append(i.find_element_by_xpath(".//a").get_attribute('href'))
    try:
        next_page=driver.find_element_by_xpath("//div[@class='a-text-center']/ul/li[@class='a-last']/a").get_attribute('href')
        driver.get(next_page)
        driver.refresh()   
    except:
        break

#Taking every URL one after one
for i in urls:
    driver.get(i)
    urls.append(i)
    driver.implicitly_wait(5)
    
#Scraping the rating
    try:
        driver.find_element_by_xpath("//a[1][@id='acrCustomerReviewLink']").click()
    except NoSuchElementException:
        print("No rating")
        pass
    
#Scraping all the reviews
    try:
        driver.find_element_by_xpath("//a[@class='a-link-emphasis a-text-bold']").click()
    except NoSuchElementException:
        pass

    
#Scrapping the details
    S_page=1
    E_page=60
    for page in range(S_page,E_page+1):
        try:
            reviews=driver.find_elements_by_xpath("//div[@class='a-row a-spacing-small review-data']/span/span")
            for r in reviews:
                review.append(r.text.replace('\n',''))
        except NoSuchElementException:
            review.append("Not Available")
        try:
            Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
            for i in Rating:
                ratings=i.get_attribute('title')
                rating.append(ratings[:3])
        except NoSuchElementException:
            rating.append("Not available")      
            
        #Printing the page scrapped
        print("Product review and rating  of page {} scraped ".format(page+1))
        
        #Looping for going to next page automatically
        try:
            next_page=driver.find_element_by_xpath("//div[@id='cm_cr-pagination_bar']/ul/li[2]/a")
            if next_page.text=='Next Page':
                next_page.click()
                time.sleep(2)
        except NoSuchElementException:
            pass
# Out:
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# Product review and rating  of page 15 scraped
# Product review and rating  of page 16 scraped
# Product review and rating  of page 17 scraped
# Product review and rating  of page 18 scraped
# Product review and rating  of page 19 scraped
# Product review and rating  of page 20 scraped
# Product review and rating  of page 21 scraped
# Product review and rating  of page 22 scraped
# Product review and rating  of page 23 scraped
# Product review and rating  of page 24 scraped
# Product review and rating  of page 25 scraped
# Product review and rating  of page 26 scraped
# Product review and rating  of page 27 scraped
# Product review and rating  of page 28 scraped
# Product review and rating  of page 29 scraped
# Product review and rating  of page 30 scraped
# Product review and rating  of page 31 scraped
# Product review and rating  of page 32 scraped
# Product review and rating  of page 33 scraped
# Product review and rating  of page 34 scraped
# Product review and rating  of page 35 scraped
# Product review and rating  of page 36 scraped
# Product review and rating  of page 37 scraped
# Product review and rating  of page 38 scraped
# Product review and rating  of page 39 scraped
# Product review and rating  of page 40 scraped
# Product review and rating  of page 41 scraped
# Product review and rating  of page 42 scraped
# Product review and rating  of page 43 scraped
# Product review and rating  of page 44 scraped
# Product review and rating  of page 45 scraped
# Product review and rating  of page 46 scraped
# Product review and rating  of page 47 scraped
# Product review and rating  of page 48 scraped
# Product review and rating  of page 49 scraped
# Product review and rating  of page 50 scraped
# Product review and rating  of page 51 scraped
# Product review and rating  of page 52 scraped
# Product review and rating  of page 53 scraped
# Product review and rating  of page 54 scraped
# Product review and rating  of page 55 scraped
# Product review and rating  of page 56 scraped
# Product review and rating  of page 57 scraped
# Product review and rating  of page 58 scraped
# Product review and rating  of page 59 scraped
# Product review and rating  of page 60 scraped
# Product review and rating  of page 61 scraped
# Product review and rating  of page 2 scraped
# Product review and rating  of page 3 scraped
# Product review and rating  of page 4 scraped
# Product review and rating  of page 5 scraped
# Product review and rating  of page 6 scraped
# Product review and rating  of page 7 scraped
# Product review and rating  of page 8 scraped
# Product review and rating  of page 9 scraped
# Product review and rating  of page 10 scraped
# Product review and rating  of page 11 scraped
# Product review and rating  of page 12 scraped
# Product review and rating  of page 13 scraped
# Product review and rating  of page 14 scraped
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-9581fad79524> in <module>
#      45             Rating=driver.find_elements_by_xpath("//div[@class='a-section celwidget']/div[2]/a[1]")
#      46             for i in Rating:
# ---> 47                 ratings=i.get_attribute('title')
#      48                 rating.append(ratings[:3])
#      49         except NoSuchElementException:
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     153         """
#     154
# --> 155         attribute_value = self.parent.execute_script(
#     156             "return (%s).apply(null, arguments);" % getAttribute_js,
#     157             self, name)
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     876         command = Command.W3C_EXECUTE_SCRIPT
#     877
# --> 878         return self.execute(command, {
#     879             'script': script,
#     880             'args': converted_args})['value']
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     420
#     421         params = self._wrap_value(params)
# --> 422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
#     424             self.error_handler.check_response(response)
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     419         data = utils.dump_json(params)
#     420         url = f"{self._url}{path}"
# --> 421         return self._request(command_info[0], url, body=data)
#     422
#     423     def _request(self, method, url, body=None):
#
# F:\Users\Admin\anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     441
#     442         if self.keep_alive:
# --> 443             resp = self._conn.request(method, url, body=body, headers=headers)
#     444             statuscode = resp.status
#     445         else:
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# F:\Users\Admin\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# F:\Users\Admin\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# F:\Users\Admin\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# F:\Users\Admin\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# F:\Users\Admin\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#Saving in a dataframe
Watchdf=pd.DataFrame({'Reviews: ':review,'Ratings: ':rating})

# %%
#Saving the data into a csv file
Watchdf.to_csv('WatchRew.csv')

# %%
Watchdf = pd.read_csv('WatchRew.csv')
Watchdf.head()
# Out:
#    Unnamed: 0                                          Reviews:   Ratings:
# 0           0  Reviewing after using it for last 3 days, boug...        5.0
# 1           1  Bought this a day backAt this price range I fe...        2.0
# 2           2  I was using OnePlus 5t for last 3 years. Thoug...        5.0
# 3           3  Writing this review after 3 months of usage.Wi...        5.0
# 4           4  Pros:Good displayStereo speakerIP68Wireless ch...        1.0

# %%
Watchdf.shape
# Out:
# (12735, 3)

# %%
rating_data = pd.concat([Lapdf,Watchdf])
rating_data.head()
# Out:
#    Unnamed: 0                                          Reviews:   Ratings:
# 0           0  Was excited for this laptop until it got deliv...        1.0
# 1           1  As with the looks its very sleek, lightweight ...        5.0
# 2           2                powerful machine but a bit heavy ..        5.0
# 3           3  its is a perfect banlance of hardware and pric...        5.0
# 4           4  Updated review after 6months of usage:All the ...        5.0

# %%
rating_data.shape
# Out:
# (29535, 3)

# %%
#Saving the data into a csv file
rating_data.to_csv('Rating_Data.csv')
